# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.1'

# %%
import sys
print(sys.platform)
# Out:
# win32

# %%
import platform
platform.system()
# Out:
# 'Windows'

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is C424-D046
#
#  Directory of C:\Users\KSull\kevinCodes\git_repos\pandas_practice\stackOverflow_2022
#
# 05/11/2022  19:21    <DIR>          .
# 05/11/2022  17:08    <DIR>          ..
# 05/11/2022  17:40    <DIR>          .ipynb_checkpoints
# 05/11/2022  19:21           223,818 practice.ipynb
# 05/11/2022  17:08             2,264 README_2022.txt
# 05/11/2022  17:08         1,005,643 so_survey_2022.pdf
# 05/11/2022  17:08       108,829,270 survey_results_public.csv
# 05/11/2022  17:08            14,471 survey_results_schema.csv
#                5 File(s)    110,075,466 bytes
#                3 Dir(s)  667,296,165,888 bytes free

# %% [markdown]
# ## Reading in CSV file
# Note that the CSV seems to have an index of its own, so we'll assign it as the DataFrame's index.

# %%
df = pd.read_csv('survey_results_public.csv', index_col="ResponseId")

# %%
# Some of the columns will not be shown by default since there are...?
pd.set_option('display.max_columns', len(df.columns))
# You can set this for 'rows' as well.

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %% [markdown]
# the `shape` **attribute** gives the number of (rows, columns) as a _tuple_

# %%
df.shape
# Out:
# (73268, 78)

# %% [markdown]
# the `info()` **method** is more thorough, and gives more information such as data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MainBranch                      73268 non-null  object
#  1   Employment                      71709 non-null  object
#  2   RemoteWork                      58958 non-null  object
#  3   CodingActivities                58899 non-null  object
#  4   EdLevel                         71571 non-null  object
#  5   LearnCode                       71580 non-null  object
#  6   LearnCodeOnline                 50685 non-null  object
#  7   LearnCodeCoursesCert            29389 non-null  object
#  8   YearsCode                       71331 non-null  object
#  9   YearsCodePro                    51833 non-null  object
#  10  DevType                         61302 non-null  object
#  11  OrgSize                         51039 non-null  object
# ...

# %% [markdown]
# Sometimes, we are given a schema to describe the columns, which is handy. Let's load that in too. Be sure to assign it to a different variable name.

# %%
schema_df = pd.read_csv("survey_results_schema.csv")
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
df.head(7)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
df.tail()
# Out:
#                                                    MainBranch  \
# ResponseId
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 73264                                     Employed, full-time
# 73265                                     Employed, full-time
# 73266                                     Employed, full-time
# 73267                                     Employed, full-time
# 73268       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 73264                               Fully remote
# 73265                             Full in-person
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %% [markdown]
# You can call columns with brackets or with dot notation (if no spaces).

# %%
df["ToolsTechHaveWorkedWith"]
# Out:
# ResponseId
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           npm
#                           ...
# 73264            Docker;Homebrew;Kubernetes;npm
# 73265                                       NaN
# 73266                                       npm
# 73267                                       NaN
# 73268    Docker;Kubernetes;npm;Pulumi;Terraform
# Name: ToolsTechHaveWorkedWith, Length: 73268, dtype: object

# %%
type(df["ToolsTechHaveWorkedWith"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### To access multiple columns at once...
# You pass in a list of column names.

# %%
lookup_list = ['Employment', 'RemoteWork', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline']
df[lookup_list]
# Out:
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5                                         Employed, full-time
# ...                                                       ...
# 73264                                     Employed, full-time
# 73265                                     Employed, full-time
# 73266                                     Employed, full-time
# 73267                                     Employed, full-time
# 73268       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                   Fully remote
# ...

# %%
df.iloc[[0,2,5], [2,3,4]]
# Out:
#                                       RemoteWork CodingActivities  \
# ResponseId
# 1                                            NaN              NaN
# 3           Hybrid (some remote, some in-person)            Hobby
# 6                                            NaN              NaN
#
#                                                     EdLevel
# ResponseId
# 1                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)

# %%
"LanguageWantToWorkWith" in df.columns
# Out:
# True

# %%
df["LanguageWantToWorkWith"].value_counts()
# Out:
# Python                                                          1021
# HTML/CSS;JavaScript;TypeScript                                   945
# Rust                                                             825
# C#                                                               568
# Go                                                               495
#                                                                 ...
# HTML/CSS;Java;JavaScript;Kotlin;MATLAB;PowerShell;Python           1
# C;C#;Dart;F#;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript        1
# C;Clojure;Elixir;Go;JavaScript;Rust;TypeScript                     1
# HTML/CSS;Java;Kotlin;Python;Scala;SQL                              1
# Bash/Shell;C#;HTML/CSS;JavaScript;Perl;PowerShell;TypeScript       1
# Name: LanguageWantToWorkWith, Length: 23952, dtype: int64

# %%
df.loc[range(1,5), "LanguageWantToWorkWith"]
# Out:
# ResponseId
# 1                                      NaN
# 2                          Rust;TypeScript
# 3    C#;C++;HTML/CSS;JavaScript;TypeScript
# 4                        C#;SQL;TypeScript
# Name: LanguageWantToWorkWith, dtype: object

# %%
df.loc[ 1:12 , 'LanguageHaveWorkedWith':'DatabaseWantToWorkWith']
# Out:
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                       JavaScript;TypeScript
# 3                           C#;C++;HTML/CSS;JavaScript;Python
# 4                                C#;JavaScript;SQL;TypeScript
# 5                 C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 6                                                     C++;Lua
# 7               C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 8                          C;C++;HTML/CSS;Java;JavaScript;SQL
# 9                                                         NaN
# 10                                          Delphi;Java;Swift
# 11           Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# ...

# %% [markdown]
# ## Indexing
# [last name generator](https://www.name-generator.org.uk/last/) I don't know why I'm using this...

# %%
people = {
    "first": ["Kevin", "Megan", "Sean", "Melody"],
    "last": ["Penmark", "Mikeson", "Hemingway", "Mistress"],
    "email": ['KevinPenmark@example.com', 'MeganMikeson@example.com', 'SeanHemingway@example.com', 'MelodyMistress@example.com'],
}

# %%
simple_df = pd.DataFrame(people)
simple_df
# Out:
#     first       last                       email
# 0   Kevin    Penmark    KevinPenmark@example.com
# 1   Megan    Mikeson    MeganMikeson@example.com
# 2    Sean  Hemingway   SeanHemingway@example.com
# 3  Melody   Mistress  MelodyMistress@example.com

# %%
simple_df.set_index('email', inplace=True)

# %%
simple_df.index
# Out:
# Index(['KevinPenmark@example.com', 'MeganMikeson@example.com',
#        'SeanHemingway@example.com', 'MelodyMistress@example.com'],
#       dtype='object', name='email')

# %%
simple_df.loc["MelodyMistress@example.com"]
# Out:
# first      Melody
# last     Mistress
# Name: MelodyMistress@example.com, dtype: object

# %%
type(simple_df.loc).__name__
# Out:
# '_LocIndexer'
